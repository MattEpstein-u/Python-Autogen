# %%
from autogen_agentchat.agents import AssistantAgent
from autogen_agentchat.conditions import TextMentionTermination
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.ui import Console
from autogen_ext.models.openai import OpenAIChatCompletionClient

# %%
model_client = OpenAIChatCompletionClient(model="gpt-4o")

planner_agent = AssistantAgent(
    "planner_agent",
    model_client=model_client,
    description="A helpful assistant that can plan trips.",
    system_message="You are a helpful assistant that can suggest a travel plan for a user based on their request.",
)

local_agent = AssistantAgent(
    "local_agent",
    model_client=model_client,
    description="A local assistant that can suggest local activities or places to visit.",
    system_message="You are a helpful assistant that can suggest authentic and interesting local activities or places to visit for a user and can utilize any context information provided.",
)

language_agent = AssistantAgent(
    "language_agent",
    model_client=model_client,
    description="A helpful assistant that can provide language tips for a given destination.",
    system_message="You are a helpful assistant that can review travel plans, providing feedback on important/critical tips about how best to address language or communication challenges for the given destination. If the plan already includes language tips, you can mention that the plan is satisfactory, with rationale.",
)

travel_summary_agent = AssistantAgent(
    "travel_summary_agent",
    model_client=model_client,
    description="A helpful assistant that can summarize the travel plan.",
    system_message="You are a helpful assistant that can take in all of the suggestions and advice from the other agents and provide a detailed final travel plan. You must ensure that the final plan is integrated and complete. YOUR FINAL RESPONSE MUST BE THE COMPLETE PLAN. When the plan is complete and all perspectives are integrated, you can respond with TERMINATE.",
)
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 model_client = OpenAIChatCompletionClient(model="gpt-4o")
#       3 planner_agent = AssistantAgent(
#       4     "planner_agent",
#       5     model_client=model_client,
#       6     description="A helpful assistant that can plan trips.",
#       7     system_message="You are a helpful assistant that can suggest a travel plan for a user based on their request.",
#       8 )
#      10 local_agent = AssistantAgent(
#      11     "local_agent",
#      12     model_client=model_client,
#      13     description="A local assistant that can suggest local activities or places to visit.",
#      14     system_message="You are a helpful assistant that can suggest authentic and interesting local activities or places to visit for a user and can utilize any context information provided.",
#      15 )
#
# File /workspaces/Python-Autogen/.venv/lib/python3.12/site-packages/autogen_ext/models/openai/_openai_client.py:1484, in OpenAIChatCompletionClient.__init__(self, **kwargs)
#    1481     if "api_key" not in copied_args and "LLAMA_API_KEY" in os.environ:
#    1482         copied_args["api_key"] = os.environ["LLAMA_API_KEY"]
# -> 1484 client = _openai_client_from_config(copied_args)
#    1485 create_args = _create_args_from_config(copied_args)
#    1487 super().__init__(
#    1488     client=client,
#    1489     create_args=create_args,
#    (...)   1493     include_name_in_message=include_name_in_message,
#    1494 )
#
# File /workspaces/Python-Autogen/.venv/lib/python3.12/site-packages/autogen_ext/models/openai/_openai_client.py:134, in _openai_client_from_config(config)
#     131 def _openai_client_from_config(config: Mapping[str, Any]) -> AsyncOpenAI:
#     132     # Shave down the config to just the OpenAI kwargs
#     133     openai_config = {k: v for k, v in config.items() if k in openai_init_kwargs}
# --> 134     return AsyncOpenAI(**openai_config)
#
# File /workspaces/Python-Autogen/.venv/lib/python3.12/site-packages/openai/_client.py:488, in AsyncOpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     486     api_key = os.environ.get("OPENAI_API_KEY")
#     487 if api_key is None:
# --> 488     raise OpenAIError(
#     489         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     490     )
#     491 if callable(api_key):
#     492     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
